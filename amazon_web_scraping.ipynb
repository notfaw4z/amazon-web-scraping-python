# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
#Function to extract product title
def get_title(soup):
    try:
        title = soup.find("span", attrs={"id":'productTitle'}).text.strip()
    except AttributeError:
        title = ""
    return title


#Function to extract price
def get_price(soup):
    try:
        price_whole = soup.find("span", attrs={'class':'a-price-whole'}).text
        price_decimal = soup.find("span", attrs={'class':'a-price-fraction'}).text
        price = price_whole + price_decimal
    except AttributeError:
        price = ""
    return price


#Function to extract the ratings
def get_rating(soup):
    try:
        rating = soup.find("span", attrs={'class':'a-icon-alt'}).text
    except AttributeError:
        rating = ""
    return rating


#Function to extract the number of reviews
def get_review_count(soup):
    try:
        review_count = soup.find("span", attrs={'id': 'acrCustomerReviewText'}).text
    except AttributeError:
        review_count = ""
    return review_count

#Function to extract Availability status
def get_availability(soup):
    try:
        available = soup.find("span", attrs = {'class': 'a-size-medium a-color-success'}).text.strip()
    except AttributeError:
        available = "Out of stock"
    return available

# %%
#Headers for request
HEADERS = ({'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.0.0 Safari/537.36', 'Accept-Language': 'en-US, en;q=0.5'})

# %%
URL ="https://www.amazon.com/s?k=laptop&crid=22BNRU1NAF8I&sprefix=laptop%2Caps%2C113&ref=nb_sb_noss_2"

# %%
#HTTP Request
webpage = requests.get(URL, headers=HEADERS)

# %%
webpage
# Out:
# <Response [200]>

# %%
#Soup Object containing all data
soup = BeautifulSoup(webpage.content, "html.parser")

# %%
#Fetch links as list of tag objects
links = soup.find_all("a", attrs={'class':'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'})

# %%
links_list = []

# %%
#Looping through all the links to extract data
for link in links:
    links_list.append(link.get('href'))

# %%
d = {"title":[], "price":[], "rating":[], "reviews":[],"availability":[]}

# %%
#Loop for extracting product details from each link
for link in links_list:
    new_webpage = requests.get("https://www.amazon.com" + link, headers=HEADERS)
    
    new_soup = BeautifulSoup(new_webpage.content, "html.parser")
    
    #Function calls
    d['title'].append(get_title(new_soup))
    d['price'].append(get_price(new_soup))
    d['rating'].append(get_rating(new_soup))
    d['reviews'].append(get_review_count(new_soup))
    d['availability'].append(get_availability(new_soup))

# %%
amazon_df = pd.DataFrame.from_dict(d)

# %%
amazon_df
# Out:
#                                                 title   price  \
# 0   Lenovo IdeaPad Gaming Chromebook - 2022 - Chro...  569.99
# 1   Lenovo IdeaPad 15.6" Laptop Newest, 20GB RAM, ...  399.98
# 2   SGIN Laptop 15.6 Inch, 4GB DDR4 128GB SSD Wind...  259.98
# 3   jumper Laptop 16 Inch FHD IPS Display (16:10),...  279.98
# 4   ASUS Vivobook Go 15 L510 Thin & Light Laptop C...  189.99
# 5   SGIN Laptop 15.6 Inch, 4GB DDR4 128GB SSD Wind...  259.98
# 6   ASUS Vivobook Go 15 L510 Thin & Light Laptop C...  189.99
# 7   jumper Laptop 16 Inch FHD IPS Display (16:10),...  279.98
# 8   Apple MacBook Air with Intel Core i5, 1.6GHz, ...  215.00
# 9   Acer Chromebook Spin 314 Convertible Laptop | ...  329.04
# 10  HP Chromebook 11a-ne0013dx 11.6 inch MediaTek ...  119.95
# 11  HP 15.6in Laptop (Intel Pentium Quad-Core N500...  229.00
# 12  Newest HP 14" HD Laptop, Windows 11, Intel Cel...  216.99
# 13  SAMSUNG 2022 14” FHD(1920 x 1080) Laptop, Wind...  165.00
# 14  SGIN 17.3 Inch Laptop with 8GB RAM 256GB SSD, ...  399.99
# 15  ASUS Chromebook C424, 14.0" 180 Degree FHD Nan...  249.99
# 16  SGIN Laptop 12GB RAM 512GB SSD, 15.6 Inch Wind...  359.99
# 17  Acer Aspire 5 A515-56-347N Slim Laptop - 15.6"...  299.99
# 18  WAICID Laptop 15.6 Inch, 512GB SSD 12GB DDR4, ...  999.00
# 19  Gateway Newest Touchscreen 11.6 HD 2-in-1 Conv...  133.00
# 20  ASUS Chromebook Vibe C55 Flip, Cloud Gaming La...  699.99
# 21  Lenovo IdeaPad 15.6" Laptop Newest, 20GB RAM, ...  399.98
# 22  Lenovo 2022 Newest Ideapad 3 Laptop, 15.6" HD ...  415.99
# 23  ASUS Vivobook Laptop L210 11.6" Ultra Thin Lap...  179.99
# 24  Dell Newest Inspiron 15 3511 Laptop, 15.6" FHD...  624.99
# 25  HP Premium 14-inch HD Thin and Light Laptop, I...  369.00
# 26  Lenovo 2022 Newest Ideapad 3 Laptop, 15.6" HD ...  379.99
# 27  MSI Thin GF63 15.6" 144Hz Gaming Laptop: 12th ...  999.00
# 28  Samsung Chromebook 4 (2021 Model) 11.6" Intel ...  127.46
# 29  HP 2023 15'' HD IPS Laptop, Windows 11, Intel ...  280.00
# 30  VILVA Portable-Monitor-for-Laptop - 15.6'' 108...  124.86
#
#                                          rating        reviews  availability
# 0                            3.9 out of 5 stars     12 ratings  Out of stock
# 1                            4.1 out of 5 stars    222 ratings      In Stock
# 2                            4.5 out of 5 stars  1,180 ratings      In Stock
# 3                            4.4 out of 5 stars  1,488 ratings  Out of stock
# 4                            4.3 out of 5 stars  1,594 ratings      In Stock
# 5                            4.5 out of 5 stars  1,180 ratings      In Stock
# 6                            4.3 out of 5 stars  1,594 ratings      In Stock
# 7                            4.4 out of 5 stars  1,488 ratings  Out of stock
# 8                            4.2 out of 5 stars  1,650 ratings     In Stock.
# 9                            4.3 out of 5 stars    473 ratings      In Stock
# 10                           4.1 out of 5 stars     26 ratings     In Stock.
# 11                           4.4 out of 5 stars  1,351 ratings  Out of stock
# 12                           4.2 out of 5 stars    986 ratings     In Stock.
# 13                           4.0 out of 5 stars    309 ratings  Out of stock
# 14                           4.3 out of 5 stars    320 ratings      In Stock
# 15  Previous page of related Sponsored Products                     In Stock
# 16                           4.4 out of 5 stars  1,253 ratings      In Stock
# 17                           4.3 out of 5 stars  2,107 ratings      In Stock
# 18                           4.2 out of 5 stars     68 ratings      In Stock
# 19                           3.9 out of 5 stars    693 ratings     In Stock.
# 20  Previous page of related Sponsored Products                     In Stock
# 21                           4.1 out of 5 stars    222 ratings      In Stock
# 22                           4.3 out of 5 stars  2,902 ratings  Out of stock
# 23                           4.3 out of 5 stars  8,309 ratings      In Stock
# 24                           4.4 out of 5 stars     53 ratings  Out of stock
# 25                           4.0 out of 5 stars    167 ratings      In Stock
# 26                           4.4 out of 5 stars    277 ratings  Out of stock
# 27                           4.5 out of 5 stars  1,798 ratings      In Stock
# 28                           4.2 out of 5 stars     81 ratings  Out of stock
# 29                           4.3 out of 5 stars     78 ratings     In Stock.
# 30                           4.9 out of 5 stars    288 ratings      In Stock

# %%
amazon_df.to_csv("amazon_laptop_data.csv", header=True, index=False)
